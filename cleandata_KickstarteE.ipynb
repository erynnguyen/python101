# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)

# %% [markdown]
# # APPLIED DATA CLEANING ON KICKSTARTER DATASET
#
# <img src='https://c3.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,w_695,g_auto,q_auto,dpr_2.6,f_auto,h_460/raayulrjgqrecunugw8y' width=600>

# %% [markdown]
# ## Remember to save a copy in drive before doing this exercise!

# %%
#@title Before you start, please login with the same email you have registered for the course {display-mode: "form"}

# !pip install -q cspyclient
import cspyclient as cs
import numpy as np

submission = cs.Submission.initialize_submission('6295e2dfbfe058001d0b884a')

submission.register_student()
# Out:
# HTML(value='\n            Please enter the email that you used to register for the course.<br />\n            …
# Text(value='', description='Your email', placeholder='Email..')
# Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), tooltip='Submit'…
# Output()

# %%
# Import pandas
import pandas as pd

# Load dataset
df = pd.read_csv('https://www.dropbox.com/s/k0fyjksq5c6cbvx/kickstarter_data.csv?dl=1', index_col=[0])

# First 5 rows of the dataframe
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09  1000.00
# 1  Narrative Film  Film & Video      USD  2017-11-01 30000.00
# 2  Narrative Film  Film & Video      USD  2013-02-26 45000.00
# 3           Music         Music      USD  2012-04-16  5000.00
# 4    Film & Video  Film & Video      USD  2015-08-29 19500.00
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28     0.00    failed        0      GB         0.00
# 1  2017-09-02 04:43:57  2421.00    failed       15      US       100.00
# 2  2013-01-12 00:20:50   220.00    failed        3      US       220.00
# 3  2012-03-17 03:24:11     1.00    failed        1      US         1.00
# 4  2015-07-04 08:35:03  1283.00  canceled       14      US      1283.00
#
#    usd_pledged_real  usd_goal_real
# 0              0.00        1533.95
# 1           2421.00       30000.00
# 2            220.00       45000.00
# 3              1.00        5000.00
# 4           1283.00       19500.00

# %% [markdown]
# **ANNOTATION**
#
# - Question: *graded* exercises to complete for score
#
# - Task: *not graded* exercises, highly recommended to follow through
#
# - Dataframe Columns:
#     - `goal`: Goal set at the launched time.
#
#     - `pledge`: Total amount of funding the project successfully called.
#
#     - `backers`: Number of investors that fund the project.
#
#     - `usd pledged`: conversion in US dollars of the pledged column (conversion done by kickstarter).
#
#     - `usd_pledge_real`: conversion in US dollars of the pledged column (conversion from Fixer.io API).
#
#     - `usd_goal_real`: conversion in US dollars of the goal column (conversion from Fixer.io API).
#
# The dataset is acquired from Kaggle.com. You can visit it here: https://www.kaggle.com/kemical/kickstarter-projects

# %% [markdown]
# 🙋🏻‍♂️ **DISCUSSION :** Discuss with your teammate to:
#
# - Understand the meaning of each column
# - Is there any column that you feel unnecessary?

# %% [markdown]
# # A. OVERVIEW AND CLEAN

# %% [markdown]
# ## **A.1** - Remove unwanted observations
# ---

# %% [markdown]
# ### Task

# %% [markdown]
# We have many columns for the pledge and goal with different conversions. For this analysis, we choose to keep only `usd_pledged_real` and `usd_goal_real`.
#
# Write one line of code to drop the columns `goal`, `pledge`, `usd pledged`.

# %%
df.drop(columns=['goal', 'pledged', 'usd pledged'], inplace=True)

# %%
# Check your dataframe again to see if the columns are successfully dropped
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline             launched  \
# 0          Poetry    Publishing      GBP  2015-10-09  2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD  2017-11-01  2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD  2013-02-26  2013-01-12 00:20:50
# 3           Music         Music      USD  2012-04-16  2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD  2015-08-29  2015-07-04 08:35:03
#
#       state  backers country  usd_pledged_real  usd_goal_real
# 0    failed        0      GB              0.00        1533.95
# 1    failed       15      US           2421.00       30000.00
# 2    failed        3      US            220.00       45000.00
# 3    failed        1      US              1.00        5000.00
# 4  canceled       14      US           1283.00       19500.00

# %% [markdown]
# For future convenience, let's rename the columns as follows:
#
# - `usd_pledged_real` --> `pledged`
# - `usd_goal_real` --> `goal`
#
# Write your code to do that below.

# %%
# YOUR CODE HERE
df = df.rename(columns={'usd_pledged_real':'pledged', 'usd_goal_real':'goal'})

# %%
# Check your dataframe again to see if your columns are successfully renamed
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline             launched  \
# 0          Poetry    Publishing      GBP  2015-10-09  2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD  2017-11-01  2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD  2013-02-26  2013-01-12 00:20:50
# 3           Music         Music      USD  2012-04-16  2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD  2015-08-29  2015-07-04 08:35:03
#
#       state  backers country  pledged     goal
# 0    failed        0      GB     0.00  1533.95
# 1    failed       15      US  2421.00 30000.00
# 2    failed        3      US   220.00 45000.00
# 3    failed        1      US     1.00  5000.00
# 4  canceled       14      US  1283.00 19500.00

# %% [markdown]
# ### Question 1 (5 pts)

# %%
#@title Q1 - EXPRESSION

submission.generate_question(0, globals(), height='100px')
# Out:
# Write an expression to check for duplications (of the whole row).
#
# Your code should return only one number, which is the total number of duplicated rows.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()
# Your current score: 0/100

# %%
# TEST YOUR CODE HERE
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Question 2 (5 pts)

# %%
#@title Q2 - EXPRESSION

submission.generate_question(1, globals(), height='100px')
# Out:
# How about duplicated values in column `name`?
#
# Write an expression that gives the number of rows with duplicated names.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()
# Your current score: 10/100

# %%
# TEST YOUR CODE HERE
df.duplicated(subset='name').sum()
# Out:
# 2896

# %% [markdown]
# ### Question 3 (5 pts)

# %%
#@title Q3 - MC SINGLE

submission.generate_question(2, globals(), height='100px')
# Out:
# Which of the following expressions selects all rows with duplicated names?
#
# <ol type="A">
#   <li><code>df(df['name'].duplicated())</code></li>
#   <li><code>df[df['name'].duplicated()]</code></li>
#   <li><code>df['name'].duplicated()</code></li>
#   <li><code>df[df.duplicated()]</code></li>
# </ol>
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value='A')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()
# Your current score: 0/100
#
# Your current score: 5/100

# %%
# TEST YOUR CODE HERE
df[df['name'].duplicated()]
# Out:
#                 ID                      name          category main_category  \
# 6379    1032645935      Cancelled (Canceled)            Design        Design
# 7743    1039093987  New EP/Music Development             Music         Music
# 8356    1042208764              The Basement            Horror  Film & Video
# 8448    1042642941                  The Gift      Film & Video  Film & Video
# 8761    1044230780                Redemption    Narrative Film  Film & Video
# ...            ...                       ...               ...           ...
# 378140   997542782              Innocent Sin        Indie Rock         Music
# 378224   997919903                Grassroots        Publishing    Publishing
# 378426   998836498              The InAction  Camera Equipment    Technology
# 378475   999055513           The Last Hurrah              Rock         Music
# 378548   999410766                     Guilt            Shorts  Film & Video
#
#        currency    deadline             launched       state  backers country  \
# 6379        USD  2015-06-05  2015-05-06 12:29:08    canceled       17      US
# 7743        USD  2016-01-07  2015-11-24 15:29:35   undefined        0    N,0"
# 8356        USD  2015-05-07  2015-04-07 18:24:19  successful      106      US
# 8448        USD  2013-05-08  2013-04-17 01:55:27  successful       37      US
# 8761        USD  2012-08-25  2012-06-26 19:13:21  successful       67      US
# ...         ...         ...                  ...         ...      ...     ...
# 378140      USD  2015-01-25  2014-12-26 18:04:28  successful       15      US
# 378224      EUR  2017-09-14  2017-08-15 18:36:18      failed        3      IE
# 378426      USD  2016-07-29  2016-06-28 04:00:08    canceled        5      US
# 378475      USD  2012-06-03  2012-05-04 15:20:41  successful       69      US
# 378548      USD  2014-05-16  2014-04-16 17:45:46      failed        7      US
#
#         pledged      goal
# 6379    3105.00 100000.00
# 7743     257.00   3800.00
# 8356   12311.00  12000.00
# 8448    3370.00   3000.00
# 8761   11440.00  11000.00
# ...         ...       ...
# 378140   600.00    300.00
# 378224    25.12  11963.01
# 378426   670.00  80000.00
# 378475  7665.00   5500.00
# 378548   791.00  65000.00
#
# [2896 rows x 12 columns]

# %% [markdown]
# ### Task

# %% [markdown]
# The table above only pick one (from the duplicated rows) to display. Let's search for all the rows that have name '**The Gift**'.

# %%
# YOUR CODE HERE
df[df['name'] =='The Gift']
# Out:
#                 ID      name      category main_category currency    deadline  \
# 5003    1025568649  The Gift        Shorts  Film & Video      USD  2014-05-10
# 8448    1042642941  The Gift  Film & Video  Film & Video      USD  2013-05-08
# 77475   1394078347  The Gift        Shorts  Film & Video      USD  2011-04-09
# 135140   168615922  The Gift        Shorts  Film & Video      USD  2011-12-31
#
#                    launched       state  backers country  pledged     goal
# 5003    2014-04-29 03:14:49  successful       27      US  4560.00  4500.00
# 8448    2013-04-17 01:55:27  successful       37      US  3370.00  3000.00
# 77475   2011-03-09 00:15:36      failed        0      US     0.00  1500.00
# 135140  2011-11-01 02:28:03      failed        0      US     0.00 10000.00

# %% [markdown]
# 🙋🏻‍♂️ **DISCUSSION**: What can you observe? Are these considered as duplication and should we drop these rows?

# %% [markdown]
# ## **A.2** - Structural Error, Correct Datatype
# ---

# %% [markdown]
# ### Task

# %% [markdown]
# Write one line of code to print the overall information of the dataset. Are there any columns that you feel like they have the wrong datatype?

# %%
# YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378661 entries, 0 to 378660
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             378661 non-null  int64
#  1   name           378657 non-null  object
#  2   category       378661 non-null  object
#  3   main_category  378661 non-null  object
#  4   currency       378661 non-null  object
#  5   deadline       378661 non-null  object
#  6   launched       378661 non-null  object
#  7   state          378661 non-null  object
#  8   backers        378661 non-null  int64
#  9   country        378661 non-null  object
#  10  pledged        378661 non-null  float64
#  11  goal           378661 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 37.6+ MB

# %% [markdown]
# The `launched` and `deadline` should be in `datetime` datatype. We follow the syntax under to change the column to datetime. Working with time will be covered next week. Worry not! 🥸

# %%
df['launched'] = pd.to_datetime(df['launched'])
df['deadline'] = pd.to_datetime(df['deadline'])

# %% [markdown]
# Check info one more time to make sure everything goes as plan.

# %%
# YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378661 entries, 0 to 378660
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             378661 non-null  int64
#  1   name           378657 non-null  object
#  2   category       378661 non-null  object
#  3   main_category  378661 non-null  object
#  4   currency       378661 non-null  object
#  5   deadline       378661 non-null  datetime64[ns]
#  6   launched       378661 non-null  datetime64[ns]
#  7   state          378661 non-null  object
#  8   backers        378661 non-null  int64
#  9   country        378661 non-null  object
#  10  pledged        378661 non-null  float64
#  11  goal           378661 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(6)
# memory usage: 37.6+ MB

# %% [markdown]
# ## **A.3** - Handling Missing Values
# ---

# %% [markdown]
# ### Question 4 (5 pts)

# %%
#@title Q4 - MC MULTIPLE

submission.generate_question(3, globals(), height='100px')
# Out:
# Which of the following expressions give the number of null values in *every* column?
#
# <ol type="A">
#   <li><code>df.isna().sum()</code></li>
#   <li><code>df.null().sum()</code></li>
#   <li><code>df.isnull().sum()</code></li>
#   <li><code>sum(df.isnull())</code></li>
#   <li><code>df.isna.sum()</code></li>
#   <li><code>sum(df.isna())</code></li>
# </ol>
# SelectMultiple(description='Your answer:', options=('A', 'B', 'C', 'D', 'E', 'F'), value=())
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df.isnull().sum()
# Out:
# ID               0
# name             4
# category         0
# main_category    0
# currency         0
# deadline         0
# launched         0
# state            0
# backers          0
# country          0
# pledged          0
# goal             0
# dtype: int64

# %% [markdown]
# ### Task

# %% [markdown]
# Write one line of code to fill all the `NaN` values in name with `Unknown`.

# %%
# YOUR CODE HERE
df['name'] = df['name'].fillna('Unknown')
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal
# 0    failed        0      GB     0.00  1533.95
# 1    failed       15      US  2421.00 30000.00
# 2    failed        3      US   220.00 45000.00
# 3    failed        1      US     1.00  5000.00
# 4  canceled       14      US  1283.00 19500.00

# %% [markdown]
# Check the number of `NaN` value one more time to make sure we cleaned them all.

# %%
# YOUR CODE HERE
df.isna().sum()
# Out:
# ID               0
# name             0
# category         0
# main_category    0
# currency         0
# deadline         0
# launched         0
# state            0
# backers          0
# country          0
# pledged          0
# goal             0
# dtype: int64

# %% [markdown]
# ## **A.4** - Handling errors, corrupted data
# ---

# %% [markdown]
# Scanning through each column to find abnormalities and fix them. Simple as that.

# %%
# Display the dataframe one more time.
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal
# 0    failed        0      GB     0.00  1533.95
# 1    failed       15      US  2421.00 30000.00
# 2    failed        3      US   220.00 45000.00
# 3    failed        1      US     1.00  5000.00
# 4  canceled       14      US  1283.00 19500.00

# %% [markdown]
# ### Question 5 (5 pts)

# %%
#@title Q5 - EXPRESSION

submission.generate_question(4, globals(), height='100px')
# Out:
# Let's start with `category`.
#
# Write an expression to display the frequency of each value in column `category`. (The unique values and how many times they appear).
#
# *Your answer should look like this:*
#
# ```
# Product Design     22314
# Documentary        16139
# Music              15727
# Tabletop Games     14180
# Shorts             12357
#                    ...
# Residencies           69
# Letterpress           49
# Chiptune              35
# Literary Spaces       27
# Taxidermy             13
# Name: category, Length: 159, dtype: int64
# ```
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df['category'].value_counts()
# Out:
# Product Design     22314
# Documentary        16139
# Music              15727
# Tabletop Games     14180
# Shorts             12357
#                    ...
# Residencies           69
# Letterpress           49
# Chiptune              35
# Literary Spaces       27
# Taxidermy             13
# Name: category, Length: 159, dtype: int64

# %% [markdown]
# ### Question 6 (5 pts)

# %%
#@title Q6 - EXPRESSION

submission.generate_question(5, globals(), height='100px')
# Out:
# Everything seems fine. We now move on to `main_category`.
#
# Write an expression to display the frequency of each value in column `main_category`.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df['main_category'].value_counts()
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64

# %% [markdown]
# ### Task

# %% [markdown]
# Let's do the same for `currency` and `state`. Find anything abnormal?

# %%
# YOUR CODE HERE
df['currency'].value_counts()
# Out:
# USD    295365
# GBP     34132
# EUR     17405
# CAD     14962
# AUD      7950
# SEK      1788
# MXN      1752
# NZD      1475
# DKK      1129
# CHF       768
# NOK       722
# HKD       618
# SGD       555
# JPY        40
# Name: currency, dtype: int64

# %%
df['state'].value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %% [markdown]
# ### Question 7 (5 pts)

# %%
#@title Q7 - MC SINGLE

submission.generate_question(6, globals(), height='100px')
# Out:
# Are there any abnormalities in the column `country`?
#
# <ol type="A">
#   <li>Nope, totally fine.</li>
#   <li>There is no project in US.</li>
#   <li>There are two different values that both represent Canada.</li>
#   <li>There is a weird value called <code>N,0"</code>.</li>
# </ol>
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value='A')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df['country'].value_counts()
# Out:
# US      292627
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %% [markdown]
# 🙋🏻‍♂️ **DISCUSSION:** Discuss with your teammate: In which way, do you think we should fix this error?
# check the currency

# %% [markdown]
# #### *Click to see my solution*

# %% [markdown]
# One way to adjust the error in the column `country` is to refer it with the column `currency`.
#
# For example, if the `currency` is `USD`, we can set the value in `country` to `US`.

# %% [markdown]
# ### Question 8 (5 pts)

# %%
#@title Q8 - EXPRESSION

submission.generate_question(7, globals(), height='100px')
# Out:
# Write an expression to select all rows with that weird value above (`N,0"`).
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df[df['country'] =='N,0"']
# Out:
#                 ID                                               name  \
# 169     1000694855                      STREETFIGHTERZ WHEELIE MURICA
# 328      100149523                        Duncan Woods - Chameleon EP
# 632     1003023003          The Making of Ashley Kelley's Debut Album
# 647     1003130892                       Butter Side Down Debut Album
# 749     1003629045                            Chase Goehring debut EP
# ...            ...                                                ...
# 378233   997971307  EQUUS International Film Festival®, all-equine...
# 378303   998319149                            Emily 2050 - Short Film
# 378434     9988744                             Matthew Stephens Music
# 378585   999610349     Lady Vendredi: Afrofuturist concept 12 inch EP
# 378588   999621278                     Jeune auteur a besoin de vous!
#
#             category main_category currency   deadline            launched  \
# 169     Film & Video  Film & Video      USD 2014-09-20 2014-08-06 21:28:36
# 328            Music         Music      AUD 2015-08-25 2015-08-04 12:05:17
# 632            Music         Music      USD 2015-04-09 2015-03-10 20:06:13
# 647            Music         Music      USD 2015-11-26 2015-11-02 22:09:19
# 749            Music         Music      USD 2016-03-21 2016-02-23 03:09:49
# ...              ...           ...      ...        ...                 ...
# 378233  Film & Video  Film & Video      USD 2015-02-03 2014-12-05 04:19:14
# 378303  Film & Video  Film & Video      CAD 2014-05-23 2014-04-08 00:30:09
# 378434         Music         Music      USD 2016-02-05 2016-01-06 21:59:23
# 378585         Music         Music      GBP 2015-10-19 2015-09-21 22:33:18
# 378588    Publishing    Publishing      EUR 2015-11-20 2015-10-21 21:28:13
#
#             state  backers country  pledged    goal
# 169     undefined        0    N,0"   555.00 6500.00
# 328     undefined        0    N,0"  3402.08 3211.53
# 632     undefined        0    N,0"  3576.00 3500.00
# 647     undefined        0    N,0"  7007.80 6000.00
# 749     undefined        0    N,0"  3660.38 3000.00
# ...           ...      ...     ...      ...     ...
# 378233  undefined        0    N,0"    10.00 7500.00
# 378303  undefined        0    N,0"  2845.61 2752.04
# 378434  undefined        0    N,0"   235.00 5000.00
# 378585  undefined        0    N,0"  3273.36 3080.81
# 378588  undefined        0    N,0"     0.00 1710.08
#
# [3797 rows x 12 columns]

# %% [markdown]
# ### Question 9 (5 pts)

# %%
#@title Q9 - EXPRESSION

submission.generate_question(8, globals(), height='100px')
# Out:
# Write an expression to return the ***unique currencies*** of the projects that have country as `N,0"`?
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df[df['country'] =='N,0"']['currency'].unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'GBP', 'EUR', 'SEK', 'DKK', 'NZD', 'NOK',
#        'CHF'], dtype=object)

# %% [markdown]
# ### Task

# %% [markdown]
# Our mission is apply a check function onto each row of the country-N0" part.
#
# First, define a function that takes in a whole data row.
#
# - If currency is `USD` ---> country is `US`
# - If currency is `AUD` ---> country is `AU`
# - If currency is `CAD` ---> country is `CA`
# - If currency is `GBP` ---> country is `GB`
# - If currency is `SEK` ---> country is `SE`
# - If currency is `DKK` ---> country is `DK`
# - If currency is `NZD` ---> country is `NZ`
# - If currency is `NOK` ---> country is `NO`
# - If currency is `CHF` ---> country is `CH`
# - If currency is `EUR` ---> country is `DE`
#
# In the `EUR` case, we choose to replace by the mode --- `DE` (Within projects that in `EUR`, the most are from `DE` -- Germany)

# %%
def fix_country(row):
    # YOUR CODE HERE
    if row['currency'] == 'USD':
      return 'US'
    elif row['currency'] == 'AUD':
      return 'AU'
    elif row['currency'] == 'CAD':
      return 'CA'
    elif row['currency'] == 'GBP':
      return 'GB'
    elif row['currency'] == 'SEK':
      return 'SE'
    elif row['currency'] == 'DDK':
      return 'DK'
    elif row['currency'] == 'NZD':
      return 'NZ'
    elif row['currency'] == 'NOK':
      return 'NO'
    elif row['currency'] == 'CHF':
      return 'CH'
    elif row['currency'] == 'EUR':
      return 'DE'

# %%
# Apply and then write it back to the dataframe
df.loc[df['country'] == 'N,0"', 'country'] = df[df['country'] == 'N,0"'].apply(fix_country, axis=1)

# %%
# Check the column again to make sure the N0" is gone
df['country'].value_counts()
# Out:
# US    295365
# GB     34132
# CA     14962
# AU      7950
# DE      4357
# FR      2939
# IT      2878
# NL      2868
# ES      2276
# SE      1788
# MX      1752
# NZ      1475
# DK      1113
# IE       811
# CH       768
# NO       722
# HK       618
# BE       617
# AT       597
# SG       555
# LU        62
# JP        40
# Name: country, dtype: int64

# %% [markdown]
# ### Question 10 (5 pts)

# %%
#@title Q10 - EXPRESSION

submission.generate_question(9, globals(), height='100px')
# Out:
# Let's move on to the numeric columns.
#
# Write an expression to give the descriptive statistics overview of three columns: `backer`, `pledged`, and `goal`.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df[['backers','pledged','goal']].describe()
# Out:
#         backers     pledged         goal
# count 378661.00   378661.00    378661.00
# mean     105.62     9058.92     45454.40
# std      907.19    90973.34   1152950.06
# min        0.00        0.00         0.01
# 25%        2.00       31.00      2000.00
# 50%       12.00      624.33      5500.00
# 75%       56.00     4050.00     15500.00
# max   219382.00 20338986.27 166361390.71

# %% [markdown]
# 💡 **Tips:** Your question right now is what the heck is `e+05` and `e+04`. This in Python called scientific style. `e+04` means `*10e4` or `*10000`.
#
# If you don't like it, you can use the syntax below. After you run the code, all the report later will be printed in 2 decimal float format.

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
# PUT YOUR ANSWER TO QUESTION 10 HERE
df[['backers','pledged','goal']].describe()
# Out:
#         backers     pledged         goal
# count 378661.00   378661.00    378661.00
# mean     105.62     9058.92     45454.40
# std      907.19    90973.34   1152950.06
# min        0.00        0.00         0.01
# 25%        2.00       31.00      2000.00
# 50%       12.00      624.33      5500.00
# 75%       56.00     4050.00     15500.00
# max   219382.00 20338986.27 166361390.71

# %% [markdown]
# Everything seems fine. No projects have abnormality in these numeric columns.

# %% [markdown]
# ### Question 11 (10 pts)

# %%
#@title Q11 - EXPRESSION

submission.generate_question(10, globals(), height='100px')
# Out:
# 👑 **The best project** --- Get row of the project that has the highest amount pledged.
#
# Your answer should be a DataFrame.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
df

# %%
df.sort_values('pledged', ascending=False)[:1]
# Out:
#                 ID                                              name  \
# 157270  1799979574  Pebble Time - Awesome Smartwatch, No Compromises
#
#               category main_category currency   deadline            launched  \
# 157270  Product Design        Design      USD 2015-03-28 2015-02-24 15:44:42
#
#              state  backers country     pledged      goal
# 157270  successful    78471      US 20338986.27 500000.00

# %%
# CODERSCHOOL SOLUTION
df[df['pledged'] == df['pledged'].max()]
# Out:
#                 ID                                              name  \
# 157270  1799979574  Pebble Time - Awesome Smartwatch, No Compromises
#
#               category main_category currency   deadline            launched  \
# 157270  Product Design        Design      USD 2015-03-28 2015-02-24 15:44:42
#
#              state  backers country     pledged      goal
# 157270  successful    78471      US 20338986.27 500000.00

# %% [markdown]
# You have done a lot of coding. Now, take a bit time off, google and read about this awesome product design project called `'Pebble Time - Awesome Smartwatch, No Compromises'` that attracts the most pledge on Kickstarter history.

# %% [markdown]
# ### Question 12 (10 pts)

# %%
#@title Q12 - EXPRESSION

submission.generate_question(11, globals(), height='100px')
# Out:
# ❤️ **The crowd favorite** --- Get row of the project that has the highest number of backers.
#
# Your answer should be a DataFrame.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()
# Your current score: 70/100

# %%
# TEST YOUR CODE HERE
df.sort_values('backers', ascending=False)[:1]
# Out:
#                 ID               name        category main_category currency  \
# 187652  1955357092  Exploding Kittens  Tabletop Games         Games      USD
#
#          deadline            launched       state  backers country    pledged  \
# 187652 2015-02-20 2015-01-20 19:00:19  successful   219382      US 8782571.99
#
#            goal
# 187652 10000.00

# %%
df.sort_values('backers', ascending=False)
# Out:
#                 ID                                               name  \
# 187652  1955357092                                  Exploding Kittens
# 75900   1386523707                      Fidget Cube: A Vinyl Desk Toy
# 292244   557230947  Bring Reading Rainbow Back for Every Child, Ev...
# 148585  1755266685                    The Veronica Mars Movie Project
# 182657  1929840910                              Double Fine Adventure
# ...            ...                                                ...
# 311336   655998102   Around The Town - A Collaborative Artist Network
# 138258  1702143571               Flye Grl Royalty For Fashion Junkies
# 311331   655973568                              Frank's Quality Meats
# 311328   655962568                                          ParkNMark
# 0       1000002330                    The Songs of Adelaide & Abullah
#
#               category main_category currency   deadline            launched  \
# 187652  Tabletop Games         Games      USD 2015-02-20 2015-01-20 19:00:19
# 75900   Product Design        Design      USD 2016-10-20 2016-08-30 22:02:09
# 292244             Web    Technology      USD 2014-07-02 2014-05-28 15:05:45
# 148585  Narrative Film  Film & Video      USD 2013-04-13 2013-03-13 15:42:22
# 182657     Video Games         Games      USD 2012-03-14 2012-02-09 02:52:52
# ...                ...           ...      ...        ...                 ...
# 311336           Music         Music      USD 2014-08-22 2014-06-23 20:11:33
# 138258         Fashion       Fashion      USD 2011-06-23 2011-05-24 02:38:35
# 311331     Small Batch          Food      USD 2015-10-01 2015-08-06 21:59:22
# 311328            Apps    Technology      CHF 2017-03-30 2017-02-28 22:33:15
# 0               Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
#
#              state  backers country    pledged       goal
# 187652  successful   219382      US 8782571.99   10000.00
# 75900   successful   154926      US 6465690.30   15000.00
# 292244  successful   105857      US 5408916.95 1000000.00
# 148585  successful    91585      US 5702153.38 2000000.00
# 182657  successful    87142      US 3336371.92  400000.00
# ...            ...      ...     ...        ...        ...
# 311336   undefined        0      US    3525.69    3500.00
# 138258      failed        0      US       0.00    1000.00
# 311331      failed        0      US       0.00    6500.00
# 311328      failed        0      CH       0.00    6296.85
# 0           failed        0      GB       0.00    1533.95
#
# [378661 rows x 12 columns]

# %% [markdown]
# Is the product sounds familiar? You can buy this at any convenient store in Vietnam nowaday. 🥳

# %% [markdown]
# ### Question 13 (10 pts)

# %%
#@title Q13 - EXPRESSION

submission.generate_question(12, globals(), height='100px')
# Out:
# 🤑 **The most ambitious** --- Get row of the project that set the highest goal.
#
# Your answer should be a DataFrame.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df.sort_values('goal', ascending=False)[:1]
# Out:
#                ID                                       name category  \
# 47803  1243678698  FUCK Potato Salad. Paleo Potato Brownies!     Food
#
#       main_category currency   deadline            launched   state  backers  \
# 47803          Food      GBP 2014-08-08 2014-07-09 00:24:34  failed        0
#
#       country  pledged         goal
# 47803      GB     0.00 166361390.71

# %% [markdown]
# ### Finally, the last two columns left are the two datetime `launched` and `deadline`.

# %% [markdown]
# ### Question 14 (10 pts)

# %%
#@title Q14 - EXPRESSION

submission.generate_question(13, globals(), height='100px')
# Out:
# Get the smallest value of column `launched`.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()
# Your current score: 80/100
#
# Your current score: 80/100
#
# Your current score: 90/100

# %%
# TEST YOUR CODE HERE
df['launched'].min()
# Out:
# Timestamp('1970-01-01 01:00:00')

# %% [markdown]
# ### Question 15 (10 pts)

# %%
#@title Q15 - EXPRESSION

submission.generate_question(14, globals(), height='100px')
# Out:
# Get the largest value of column `launched`.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# HBox(children=(Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), t…
# Output()

# %%
# TEST YOUR CODE HERE
df['launched'].max()
# Out:
# Timestamp('2018-01-02 15:02:31')

# %% [markdown]
# - The earliest data --- 1970 doesn't make sense at all. So we filter out all the data that set launched year before the founding of Kickstarter (2009).
#
# - The latest data is in the second day of 2018. That's not enough to have a view for 2018 and might effect to analysis in year level, or month level. So we exclude the incomplete data of 2018.

# %%
# Choose to work with data from the beginning of the year 2009 to the end of the year 2017 only.
df = df[(df['launched'] > '2008') & (df['launched'] < '2018')]

# %%
# Check the column one more time
df['launched'].min()
# Out:
# Timestamp('2009-04-21 21:02:48')

# %%
df['launched'].max()
# Out:
# Timestamp('2017-12-31 23:37:20')

# %% [markdown]
# ### Final Task
#
# The last task that we should do in cleaning this dataset is to create new columns extract `day`, `month`, `year` from the two columns `launched` and `deadline`. This will help us in the future when we analyse on year, on month, or on day. For example: number of project by year.
#
# In data analysis, this is a simple feature engineering.

# %% [markdown]
# On a ```datetime``` datatype column, you can simply call `<column_name>.dt.<time_unit>` to extract the value out.
#
# ```python
# date_series.dt.year
# date_series.dt.month
# date_series.dt.day
# date_series.dt.hour
# date_series.dt.minute
# date_series.dt.second
# date_series.dt.week
# date_series.dt.quarter
# ```
#
# For example:

# %%
df['launched_day'] = df['launched'].dt.day
df['launched_month'] = df['launched'].dt.month
df['launched_year'] = df['launched'].dt.year

# %%
# Do the same thing with deadline column
# YOUR CODE HERE
df['deadline_day'] = df['deadline'].dt.day
df['deadline_month'] = df['deadline'].dt.month
df['deadline_year'] = df['deadline'].dt.year

# %% [markdown]
# YAYYY!!! WE HAVE DONE EVERTHING. 🤩 Finally you got a clean dataset that is ready for analysis.
#
# Let's view out beautiful dataset again.

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency   deadline            launched  \
# 0                Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1        Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2        Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3                 Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4          Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
# ...                 ...           ...      ...        ...                 ...
# 378656      Documentary  Film & Video      USD 2014-10-17 2014-09-17 02:35:30
# 378657   Narrative Film  Film & Video      USD 2011-07-19 2011-06-22 03:35:14
# 378658   Narrative Film  Film & Video      USD 2010-08-16 2010-07-01 19:40:30
# 378659       Technology    Technology      USD 2016-02-13 2016-01-13 18:13:53
# 378660  Performance Art           Art      USD 2011-08-16 2011-07-19 09:07:47
#
#            state  backers country  pledged     goal  deadline_day  \
# 0         failed        0      GB     0.00  1533.95             9
# 1         failed       15      US  2421.00 30000.00             1
# 2         failed        3      US   220.00 45000.00            26
# 3         failed        1      US     1.00  5000.00            16
# 4       canceled       14      US  1283.00 19500.00            29
# ...          ...      ...     ...      ...      ...           ...
# 378656  canceled        1      US    25.00 50000.00            17
# 378657    failed        5      US   155.00  1500.00            19
# 378658    failed        1      US    20.00 15000.00            16
# 378659    failed        6      US   200.00 15000.00            13
# 378660    failed       17      US   524.00  2000.00            16
#
#         deadline_month  deadline_year  launched_day  launched_month  \
# 0                   10           2015            11               8
# 1                   11           2017             2               9
# 2                    2           2013            12               1
# 3                    4           2012            17               3
# 4                    8           2015             4               7
# ...                ...            ...           ...             ...
# 378656              10           2014            17               9
# 378657               7           2011            22               6
# 378658               8           2010             1               7
# 378659               2           2016            13               1
# 378660               8           2011            19               7
#
#         launched_year
# 0                2015
# 1                2017
# 2                2013
# 3                2012
# 4                2015
# ...               ...
# 378656           2014
# 378657           2011
# 378658           2010
# 378659           2016
# 378660           2011
#
# [378530 rows x 18 columns]

# %% [markdown]
# As you can see, cleaning data is a meticulous process that takes a lot of time. In real life, it can take up to days and requires a lot of domain knowledge. Treat this notebook as a guideline or a case study to start with. Be creative when adapt to your personal project! Good luck 🥸 🧚🏻‍♂️

# %% [markdown]
# # B. FUN TASK:

# %% [markdown]
# Using IQR to filter the projects that set the goal way too ambitious or too humble.

# %%
# Create a new column called 'exceed' which is the difference of 'pledged' and 'goal'
# YOUR CODE HERE
df['exceed'] = df['pledged'] - df['goal']
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency   deadline            launched  \
# 0                Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1        Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2        Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3                 Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4          Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
# ...                 ...           ...      ...        ...                 ...
# 378656      Documentary  Film & Video      USD 2014-10-17 2014-09-17 02:35:30
# 378657   Narrative Film  Film & Video      USD 2011-07-19 2011-06-22 03:35:14
# 378658   Narrative Film  Film & Video      USD 2010-08-16 2010-07-01 19:40:30
# 378659       Technology    Technology      USD 2016-02-13 2016-01-13 18:13:53
# 378660  Performance Art           Art      USD 2011-08-16 2011-07-19 09:07:47
#
#            state  backers country  pledged     goal  deadline_day  \
# 0         failed        0      GB     0.00  1533.95             9
# 1         failed       15      US  2421.00 30000.00             1
# 2         failed        3      US   220.00 45000.00            26
# 3         failed        1      US     1.00  5000.00            16
# 4       canceled       14      US  1283.00 19500.00            29
# ...          ...      ...     ...      ...      ...           ...
# 378656  canceled        1      US    25.00 50000.00            17
# 378657    failed        5      US   155.00  1500.00            19
# 378658    failed        1      US    20.00 15000.00            16
# 378659    failed        6      US   200.00 15000.00            13
# 378660    failed       17      US   524.00  2000.00            16
#
#         deadline_month  deadline_year  launched_day  launched_month  \
# 0                   10           2015            11               8
# 1                   11           2017             2               9
# 2                    2           2013            12               1
# 3                    4           2012            17               3
# 4                    8           2015             4               7
# ...                ...            ...           ...             ...
# 378656              10           2014            17               9
# 378657               7           2011            22               6
# 378658               8           2010             1               7
# 378659               2           2016            13               1
# 378660               8           2011            19               7
#
#         launched_year    exceed
# 0                2015  -1533.95
# 1                2017 -27579.00
# 2                2013 -44780.00
# 3                2012  -4999.00
# 4                2015 -18217.00
# ...               ...       ...
# 378656           2014 -49975.00
# 378657           2011  -1345.00
# 378658           2010 -14980.00
# 378659           2016 -14800.00
# 378660           2011  -1476.00
#
# [378530 rows x 19 columns]

# %%
# Now apply IQR on the column 'exceed', calculate the upper whisker and lower whisker
# YOUR CODE HERE
# 1. Calculate the quantiles 
q1 = df['exceed'].quantile(0.25) # Tính Q1
q3 = df['exceed'].quantile(0.75) # Tính Q3 

# 2. Calculate the interquantile range
iqr = q3 - q1
iqr

# # 3. Calculate the whisker: vùng bình thường của dataset nằm trong khoảng upper và lower
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr# 1. Calculate the quantiles 
q1 = df['exceed'].quantile(0.25) # Tính Q1
q3 = df['exceed'].quantile(0.75) # Tính Q3 

# 2. Calculate the interquantile range
iqr = q3 - q1
iqr

# # 3. Calculate the whisker: vùng bình thường của dataset nằm trong khoảng upper và lower
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# %%
upper
# Out:
# 15498.5

# %%
lower
# Out:
# -25297.5

# %% [markdown]
# Everything above the upper whisker means that the project attracts A LOT of money compared to its original goal.

# %%
# Filter out the projects that above the upper whisker.
# YOUR CODE HERE
df[df['exceed'] > upper]
# Out:
#                 ID                                               name  \
# 14      1000057089  Tombstone: Old West tabletop game and miniatur...
# 27      1000104688                                Permaculture Skills
# 31      1000117861                  Ledr workbook: one tough journal!
# 46      1000183112                            Hot Chicken Takes Over.
# 63      1000235643                                       HIIT Bottle™
# ...            ...                                                ...
# 378382   998630521  Hideout Pack - The Everyday Commute, Carry, Tr...
# 378437   998899601           Eminent Domain: Battlecruisers & Exotica
# 378494   999151837   Kev Adams / Tim Prow Oldhammer Goblin Miniatures
# 378540   999357376          Kodiak Leather - Classic Weekender Duffel
# 378564   999489456               Cthulhu's Chaos - Unique Dice Towers
#
#               category main_category currency   deadline            launched  \
# 14      Tabletop Games         Games      GBP 2017-05-03 2017-04-05 19:44:18
# 27           Webseries  Film & Video      CAD 2014-12-14 2014-11-14 18:02:00
# 31      Product Design        Design      USD 2016-10-08 2016-09-07 13:14:26
# 46         Restaurants          Food      USD 2014-10-16 2014-09-16 02:31:08
# 63              Drinks          Food      USD 2015-04-27 2015-03-13 18:33:08
# ...                ...           ...      ...        ...                 ...
# 378382  Product Design        Design      USD 2017-08-30 2017-07-12 17:57:01
# 378437  Tabletop Games         Games      USD 2015-07-01 2015-06-04 17:42:58
# 378494  Tabletop Games         Games      USD 2017-02-24 2017-02-08 22:02:49
# 378540     Accessories       Fashion      USD 2017-09-08 2017-07-25 16:32:20
# 378564  Tabletop Games         Games      USD 2013-10-12 2013-08-13 07:11:56
#
#              state  backers country   pledged     goal  deadline_day  \
# 14      successful      761      GB 121857.33  6469.73             3
# 27      successful      571      CA  42174.03 15313.04            14
# 31      successful      549      US  47266.00  1000.00             8
# 46      successful      855      US  63401.00 40000.00            16
# 63      successful     2784      US 124998.00 15000.00            27
# ...            ...      ...     ...       ...      ...           ...
# 378382  successful      487      US  94964.00 15000.00            30
# 378437  successful     2314      US 110319.00 30000.00             1
# 378494  successful      213      US  18361.00  1100.00            24
# 378540  successful      839      US 252311.00  5000.00             8
# 378564  successful      368      US  28931.00  1000.00            12
#
#         deadline_month  deadline_year  launched_day  launched_month  \
# 14                   5           2017             5               4
# 27                  12           2014            14              11
# 31                  10           2016             7               9
# 46                  10           2014            16               9
# 63                   4           2015            13               3
# ...                ...            ...           ...             ...
# 378382               8           2017            12               7
# 378437               7           2015             4               6
# 378494               2           2017             8               2
# 378540               9           2017            25               7
# 378564              10           2013            13               8
#
#         launched_year    exceed
# 14               2017 115387.60
# 27               2014  26860.99
# 31               2016  46266.00
# 46               2014  23401.00
# 63               2015 109998.00
# ...               ...       ...
# 378382           2017  79964.00
# 378437           2015  80319.00
# 378494           2017  17261.00
# 378540           2017 247311.00
# 378564           2013  27931.00
#
# [11766 rows x 19 columns]

# %% [markdown]
# Everything below the upper whisker means that the project set the goal way TOO HIGH compared to its real potential.

# %%
# Filter out the projects that below the lower whisker.
# YOUR CODE HERE
df[df['exceed'] < lower]
# Out:
#                 ID                                               name  \
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 13      1000056157  G-Spot Place for Gamers to connect with eachot...
# ...            ...                                                ...
# 378592     9996452  Onit Saves The World! Let's make this game one...
# 378615   999764111  Bully For You!!!  Giving Birth to the "Awww" F...
# 378626   999810803                              The Finger (Canceled)
# 378641    99991751   Here is the oasis for the youngest in the world.
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
#
#               category main_category currency   deadline            launched  \
# 1       Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2       Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 8       Product Design        Design      USD 2014-05-29 2014-04-24 18:14:43
# 9          Documentary  Film & Video      USD 2014-08-10 2014-07-11 21:55:48
# 13               Games         Games      USD 2016-03-25 2016-02-09 23:01:12
# ...                ...           ...      ...        ...                 ...
# 378592     Video Games         Games      CAD 2013-10-25 2013-09-25 22:13:27
# 378615  Product Design        Design      USD 2014-03-03 2014-02-01 22:00:47
# 378626     Documentary  Film & Video      USD 2010-12-31 2010-12-01 21:41:15
# 378641  Product Design        Design      CHF 2015-09-04 2015-07-06 18:00:47
# 378656     Documentary  Film & Video      USD 2014-10-17 2014-09-17 02:35:30
#
#            state  backers country  pledged      goal  deadline_day  \
# 1         failed       15      US  2421.00  30000.00             1
# 2         failed        3      US   220.00  45000.00            26
# 8       canceled       58      US  8233.00 125000.00            29
# 9       canceled       43      US  6240.57  65000.00            10
# 13        failed        0      US     0.00 200000.00            25
# ...          ...      ...     ...      ...       ...           ...
# 378592    failed        4      CA   532.67 359264.23            25
# 378615    failed       13      US  5652.00  33975.00             3
# 378626  canceled        1      US    50.00  28559.00            31
# 378641    failed        0      CH     0.00  82207.27             4
# 378656  canceled        1      US    25.00  50000.00            17
#
#         deadline_month  deadline_year  launched_day  launched_month  \
# 1                   11           2017             2               9
# 2                    2           2013            12               1
# 8                    5           2014            24               4
# 9                    8           2014            11               7
# 13                   3           2016             9               2
# ...                ...            ...           ...             ...
# 378592              10           2013            25               9
# 378615               3           2014             1               2
# 378626              12           2010             1              12
# 378641               9           2015             6               7
# 378656              10           2014            17               9
#
#         launched_year     exceed
# 1                2017  -27579.00
# 2                2013  -44780.00
# 8                2014 -116767.00
# 9                2014  -58759.43
# 13               2016 -200000.00
# ...               ...        ...
# 378592           2013 -358731.56
# 378615           2014  -28323.00
# 378626           2010  -28509.00
# 378641           2015  -82207.27
# 378656           2014  -49975.00
#
# [48313 rows x 19 columns]

# %% [markdown]
# From here, you can further explore the "too successful" projects and the "too failed" projects. For example, what kind of category tend to be too-successful, what opposite? Which country they are from? etc.
#
# Feel free to code and post your insights to Discord. HAVE FUNNN 🧙🏻‍♂️
